# %%
import csv
import psycopg2 as pg2
import math

# %%
# connect db
dbName = "coviddb"
dbUser = "postgres"
dbPass = "Pgis@rti2dss@2020"
dbHost = "119.59.125.134"
dbPort = "5432"

conn = pg2.connect(database=dbName, user=dbUser,
                   password=dbPass, host=dbHost, port=dbPort)
conn.autocommit = True
cursor = conn.cursor()

# %%
def insertDb(dat):
    sql = '''INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
        '{txn_date}','{gender}',{age_number},'{age_range}','{nationality}','{job}','{risk}','{patient_type}','{province}')'''.format(
        txn_date=dat[0],gender=dat[2],age_number=dat[3],age_range=dat[4],nationality=dat[5],job=dat[6],risk=dat[7],patient_type=dat[8],province=dat[9])
    
    print(sql)
    cursor.execute(sql)

# %%
csv_file = open('round-1to2-line-lists.csv')
csv_reader = csv.reader(csv_file, delimiter=',')
i = 0
for row in csv_reader:
    if i > 0:
        insertDb(row)
    i+=1
# Out:
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-12','หญิง',61,'60-69 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','1.คัดกรองจากด่าน','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-17','หญิง',74,'>= 70 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','1.คัดกรองจากด่าน','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-22','หญิง',73,'>= 70 ปี','Thai','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','นครปฐม')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-22','ชาย',68,'60-69 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-24','หญิง',66,'60-69 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-25','หญิง',33,'30-39 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-26','หญิง',57,'50-59 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-26','หญิง',73,'>= 70 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','1.คัดกรองจากด่าน','ประจวบคีรีขันธ์')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-28','หญิง',28,'20-29 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-28','ชาย',33,'30-39 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-28','ชาย',61,'60-69 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-28','ชาย',6,'< 10 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-28','หญิง',32,'30-39 ปี','Chinese','พนักงานบริษัท/โรงงาน','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','ภูเก็ต')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-28','ชาย',63,'60-69 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-31','ชาย',56,'50-59 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-31','ชาย',50,'50-59 ปี','Thai','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-31','ชาย',28,'20-29 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','เชียงใหม่')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-31','ชาย',30,'30-39 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-01-31','ชาย',33,'30-39 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-04','หญิง',43,'40-49 ปี','Thai','นักท่องเที่ยว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-04','ชาย',49,'40-49 ปี','Thai','นักท่องเที่ยว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-04','ชาย',33,'30-39 ปี','Chinese','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-04','ชาย',45,'40-49 ปี','Thai','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','2.สัมผัสผู้ติดเชื้อ','ประจวบคีรีขันธ์')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-04','หญิง',31,'30-39 ปี','Chinese','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กระบี่')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-04','ชาย',70,'>= 70 ปี','Thai','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','ชาย',36,'30-39 ปี','Chinese','ค้าขาย/ธุรกิจส่วนตัว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','ภูเก็ต')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','ชาย',35,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','หญิง',56,'50-59 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','หญิง',32,'30-39 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','ชาย',62,'60-69 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','หญิง',3,'< 10 ปี','Thai','เด็กเล็ก/ในปกครอง','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-08','ชาย',24,'20-29 ปี','Thai','มัคคุเทศก์/ไกด์ทัวร์','State Quarantine','4.คนไทยมาจากต่างประเทศ','ชลบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-11','หญิง',55,'50-59 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-15','หญิง',35,'30-39 ปี','Thai','พยาบาล','บุคลากรด้านการแพทย์และสาธารณสุข','2.สัมผัสผู้ติดเชื้อ','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-17','หญิง',69,'60-69 ปี','Chinese','นักท่องเที่ยว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-25','หญิง',31,'30-39 ปี','Thai','ว่างงาน','ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-25','ชาย',29,'20-29 ปี','Thai','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-26','ชาย',64,'60-69 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-26','หญิง',62,'60-69 ปี','Thai','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-26','ชาย',8,'< 10 ปี','Thai','นักเรียน/นักศึกษา','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-28','ชาย',25,'20-29 ปี','Thai','มัคคุเทศก์/ไกด์ทัวร์','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','4.คนไทยมาจากต่างประเทศ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-02-29','ชาย',21,'20-29 ปี','Thai','พนักงานบริษัท/โรงงาน','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-02','หญิง',22,'20-29 ปี','Thai','พนักงานในสถานบันเทิง','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-05','ชาย',29,'20-29 ปี','Italian','พนักงานบริษัท/โรงงาน','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','ชลบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-05','ชาย',41,'40-49 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','ชลบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-05','ชาย',24,'20-29 ปี','Chinese','นักเรียน/นักศึกษา','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','1.คัดกรองจากด่าน','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-05','ชาย',22,'20-29 ปี','Thai','นักเรียน/นักศึกษา','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','นครศรีธรรมราช')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-06','ชาย',43,'40-49 ปี','British','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-07','ชาย',40,'40-49 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-07','ชาย',39,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-10','หญิง',41,'40-49 ปี','Thai','HCW (บุคลากรทางการแพทย์)','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','สุพรรณบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-10','หญิง',46,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-10','ชาย',47,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-11','ชาย',21,'20-29 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-11','ชาย',40,'40-49 ปี','Thai','เจ้าหน้าที่สนามบิน','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-11','ชาย',25,'20-29 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-11','หญิง',27,'20-29 ปี','Thai','ว่างงาน','สถานบันเทิง','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-11','ชาย',40,'40-49 ปี','Thai','ไม่ระบุ','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-11','ชาย',36,'30-39 ปี','Singaporean','ค้าขาย/ธุรกิจส่วนตัว','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',29,'20-29 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','ชาย',32,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',33,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','ชาย',32,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',38,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',37,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',37,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',26,'20-29 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','ชาย',37,'30-39 ปี','Thai','ไม่ระบุ','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',25,'20-29 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',34,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','หญิง',36,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-12','ชาย',37,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-13','ชาย',19,'10-19 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-13','หญิง',29,'20-29 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-13','ชาย',37,'30-39 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','หญิง',63,'60-69 ปี','Thai','ไม่ระบุ','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','หญิง',57,'50-59 ปี','Thai','ไม่ระบุ','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','หญิง',30,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','สัมผัสผู้เดินทางจากต่างประเทศ','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','ชาย',33,'30-39 ปี','Japanese','นักท่องเที่ยว','สัมผัสผู้เดินทางจากต่างประเทศ','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','หญิง',4,'< 10 ปี','Thai','เด็กเล็ก/ในปกครอง','สัมผัสผู้เดินทางจากต่างประเทศ','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','หญิง',20,'20-29 ปี','Thai','ไม่ระบุ','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-14','ชาย',41,'40-49 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',38,'30-39 ปี','Thai','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',32,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',28,'20-29 ปี','Japanese','0','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',76,'>= 70 ปี','Thai','ไม่ระบุ','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',41,'40-49 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',68,'60-69 ปี','Thai','ว่างงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',41,'40-49 ปี','Thai','เจ้าหน้าที่สนามบิน','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',51,'50-59 ปี','French','เจ้าหน้าที่บนเครื่องบิน','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',27,'20-29 ปี','Thai','พนักงานบริษัท/โรงงาน','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',29,'20-29 ปี','Thai','พนักงานบริษัท/โรงงาน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',34,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',39,'30-39 ปี','Thai','พนักงานในสถานบันเทิง','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',47,'40-49 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',40,'40-49 ปี','Thai','0','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',41,'40-49 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',29,'20-29 ปี','Thai','อื่นๆ','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',53,'50-59 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',39,'30-39 ปี','Thai','ไม่ระบุ','สนามมวย','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',21,'20-29 ปี','Thai','นักเรียน/นักศึกษา','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',41,'40-49 ปี','Thai','0','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',30,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',59,'50-59 ปี','Thai','พนักงานบริษัท/โรงงาน','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',62,'60-69 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',48,'40-49 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',37,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','10.อื่นๆ','เชียงใหม่')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',39,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',33,'30-39 ปี','Thai','พนักงานร้านอาหาร','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',27,'20-29 ปี','Thai','พนักงานร้านอาหาร','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',30,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','ชาย',31,'30-39 ปี','Thai','0','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',33,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','0','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-15','หญิง',38,'30-39 ปี','Thai','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',42,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',58,'50-59 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',25,'20-29 ปี','Thai','0','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',46,'40-49 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',35,'30-39 ปี','Thai','อื่นๆ','สนามมวย','10.อื่นๆ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',73,'>= 70 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',51,'50-59 ปี','Thai','0','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',29,'20-29 ปี','Thai','0','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',21,'20-29 ปี','Thai','นักเรียน/นักศึกษา','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',23,'20-29 ปี','Thai','พนักงานในสถานบันเทิง','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',35,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',51,'50-59 ปี','Thai','พนักงานบริษัท/โรงงาน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',36,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','สุโขทัย')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',37,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',56,'50-59 ปี','Thai','พนักงานบริษัท/โรงงาน','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',32,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',44,'40-49 ปี','Thai','พนักงานโรงแรม','คนไทยเดินทางกลับจากต่างประเทศ','1.คัดกรองจากด่าน','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',36,'30-39 ปี','French','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',47,'40-49 ปี','Thai','ว่างงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',29,'20-29 ปี','Thai','0','สัมผัสผู้เดินทางจากต่างประเทศ','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',26,'20-29 ปี','Thai','0','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',35,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',33,'30-39 ปี','Thai','0','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',47,'40-49 ปี','Thai','0','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',47,'40-49 ปี','Thai','0','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',50,'50-59 ปี','Thai','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','0','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',48,'40-49 ปี','Danish','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','0','3.ต่างชาติมาจากต่างประเทศ','ภูเก็ต')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',39,'30-39 ปี','Danish','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','0','3.ต่างชาติมาจากต่างประเทศ','ภูเก็ต')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','หญิง',7,'< 10 ปี','Danish','นักเรียน/นักศึกษา','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','ภูเก็ต')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',55,'50-59 ปี','Thai','เกษตรกร (ปลูกพืช)','พิธีกรรมทางศาสนา','4.คนไทยมาจากต่างประเทศ','นราธิวาส')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',64,'60-69 ปี','Thai','เกษตรกร (ปลูกพืช)','พิธีกรรมทางศาสนา','4.คนไทยมาจากต่างประเทศ','ยะลา')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',67,'60-69 ปี','Belgian','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','เพชรบูรณ์')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-16','ชาย',62,'60-69 ปี','American','ว่างงาน','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',36,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',23,'20-29 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',33,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',56,'50-59 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',27,'20-29 ปี','Thai','0','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',30,'30-39 ปี','Thai','0','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',61,'60-69 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','10.อื่นๆ','ชลบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',34,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',59,'50-59 ปี','Thai','0','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',28,'20-29 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',79,'>= 70 ปี','Thai','ว่างงาน','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','หญิง',26,'20-29 ปี','Thai','0','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',39,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',14,'10-19 ปี','Thai','นักเรียน/นักศึกษา','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','สุราษฎร์ธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',25,'20-29 ปี','German','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',46,'40-49 ปี','Thai','0','พิธีกรรมทางศาสนา','4.คนไทยมาจากต่างประเทศ','ปัตตานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',41,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','พิธีกรรมทางศาสนา','4.คนไทยมาจากต่างประเทศ','นราธิวาส')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',72,'>= 70 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','พิธีกรรมทางศาสนา','4.คนไทยมาจากต่างประเทศ','ปัตตานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','หญิง',32,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','หญิง',31,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',39,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','หญิง',23,'20-29 ปี','Thai','0','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',49,'40-49 ปี','Thai','พนักงานโรงแรม','คนไทยเดินทางกลับจากต่างประเทศ','4.คนไทยมาจากต่างประเทศ','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',47,'40-49 ปี','Thai','พนักงานขับรถโดยสาร/รถตู้/แท๊กซี่','อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',40,'40-49 ปี','Pakistani','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',44,'40-49 ปี','Italian','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',39,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',52,'50-59 ปี','Canadian','นักท่องเที่ยว','คนต่างชาติเดินทางมาจากต่างประเทศ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',49,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สัมผัสผู้เดินทางจากต่างประเทศ','2.สัมผัสผู้ติดเชื้อ','สุราษฎร์ธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-17','ชาย',22,'20-29 ปี','Thai','0','สถานบันเทิง','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',44,'40-49 ปี','Thai','0','สนามมวย','2.สัมผัสผู้ติดเชื้อ','สมุทรปราการ')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',76,'>= 70 ปี','Thai','ว่างงาน','สนามมวย','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',34,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',42,'40-49 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',33,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สนามมวย','9.ขอตรวจหาเชื้อเอง','ขอนแก่น')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',37,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',40,'40-49 ปี','Thai','พนักงานบริษัท/โรงงาน','สนามมวย','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',31,'30-39 ปี','Thai','0','สนามมวย','2.สัมผัสผู้ติดเชื้อ','เชียงใหม่')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',36,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','2.สัมผัสผู้ติดเชื้อ','ร้อยเอ็ด')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',55,'50-59 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สนามมวย','9.ขอตรวจหาเชื้อเอง','กาฬสินธุ์')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',50,'50-59 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','สนามมวย','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',57,'50-59 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','สนามมวย','9.ขอตรวจหาเชื้อเอง','นครราชสีมา')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',48,'40-49 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','สนามมวย','10.อื่นๆ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2020-03-18','ชาย',32,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
# ...
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-03','ไม่ระบุ',0,'ไม่ระบุ','0','','Cluster สมุทรสาคร','8.สำรวจกลุ่มเสี่ยง (survey)','สมุทรสาคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',9,'< 10 ปี','Thai','0','','10.อื่นๆ','จันทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',36,'30-39 ปี','Thai','ว่างงาน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',44,'40-49 ปี','Thai','ไม่ระบุ','ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว','9.ขอตรวจหาเชื้อเอง','นครปฐม')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',43,'40-49 ปี','Thai','ไม่ระบุ','ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต','9.ขอตรวจหาเชื้อเอง','นครปฐม')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',29,'20-29 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว','2.สัมผัสผู้ติดเชื้อ','นนทบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',34,'30-39 ปี','Thai','ไม่ระบุ','Cluster บ่อนพัทยา/ชลบุรี','2.สัมผัสผู้ติดเชื้อ','พระนครศรีอยุธยา')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',50,'50-59 ปี','Thai','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','Cluster สมุทรสาคร','9.ขอตรวจหาเชื้อเอง','สุราษฎร์ธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',24,'20-29 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',18,'10-19 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',32,'30-39 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',30,'30-39 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',25,'20-29 ปี','Thai','ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',33,'30-39 ปี','Thai','พนักงานร้านอาหาร','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',25,'20-29 ปี','Thai','พนักงานร้านอาหาร','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',27,'20-29 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',27,'20-29 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',26,'20-29 ปี','Thai','พนักงานร้านอาหาร','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',51,'50-59 ปี','Thai','พนักงานร้านอาหาร','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',26,'20-29 ปี','Thai','ว่างงาน','สถานบันเทิง','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',12,'10-19 ปี','Thai','นักเรียน/นักศึกษา','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',10,'10-19 ปี','Thai','นักเรียน/นักศึกษา','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',19,'10-19 ปี','Thai','พนักงานในสถานบันเทิง','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',38,'30-39 ปี','Burmese','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',22,'20-29 ปี','Thai','พนักงานในสถานบันเทิง','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',47,'40-49 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน','8.สำรวจกลุ่มเสี่ยง (survey)','ชัยนาท')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',58,'50-59 ปี','Thai','เกษตรกร (เลี้ยงสัตว์)','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',38,'30-39 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',37,'30-39 ปี','Thai','เกษตรกร (เลี้ยงสัตว์)','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',64,'60-69 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',51,'50-59 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',44,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',60,'60-69 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',36,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',31,'30-39 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',13,'10-19 ปี','Thai','นักเรียน/นักศึกษา','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',52,'50-59 ปี','Thai','รับจ้างทั่วไป / ฟรีแลนซ์','Cluster บ่อนไก่อ่างทอง','9.ขอตรวจหาเชื้อเอง','อ่างทอง')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',62,'60-69 ปี','Thai','0','ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว','2.สัมผัสผู้ติดเชื้อ','เพชรบุรี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',32,'30-39 ปี','Burmese','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',26,'20-29 ปี','Burmese','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',31,'30-39 ปี','Burmese','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',9,'< 10 ปี','Burmese','ไม่ระบุ','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',34,'30-39 ปี','Burmese','ว่างงาน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',28,'20-29 ปี','Burmese','รับจ้างทั่วไป / ฟรีแลนซ์','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ปทุมธานี')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',81,'>= 70 ปี','Thai','ไม่ระบุ','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','พิจิตร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',83,'>= 70 ปี','Thai','ไม่ระบุ','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','พิจิตร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',53,'50-59 ปี','Thai','0','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','พิจิตร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',61,'60-69 ปี','Thai','พ่อบ้าน/แม่บ้าน/ดูแลบ้าน','สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้','2.สัมผัสผู้ติดเชื้อ','ประจวบคีรีขันธ์')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','หญิง',33,'30-39 ปี','Thai','พนักงานบริษัท/โรงงาน','ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',41,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','สถานบันเทิง','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',30,'30-39 ปี','Japanese','พนักงานบริษัท/โรงงาน','ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ','3.ต่างชาติมาจากต่างประเทศ','กรุงเทพมหานคร')
# INSERT INTO _covidth_r12(txn_date,gender,age_number,age_range,nationality,job,risk,patient_type,province)VALUES(
#         '2021-01-04','ชาย',43,'40-49 ปี','Thai','ค้าขาย/ธุรกิจส่วนตัว','Cluster Memory 90's กทม.','9.ขอตรวจหาเชื้อเอง','กรุงเทพมหานคร')
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /var/folders/b3/x53y95x96790jxqq5l84_bfr0000gn/T/ipykernel_62934/3731074914.py in <module>
#       4 for row in csv_reader:
#       5     if i > 0:
# ----> 6         insertDb(row)
#       7     i+=1
#
# /var/folders/b3/x53y95x96790jxqq5l84_bfr0000gn/T/ipykernel_62934/3776675386.py in insertDb(dat)
#       5
#       6     print(sql)
# ----> 7     cursor.execute(sql)
#
# SyntaxError: syntax error at or near "s"
# LINE 2: ...,'Thai','ค้าขาย/ธุรกิจส่วนตัว','Cluster Memory 90's กทม.','9...
#                                                              ^
